# %% [markdown]
# # PANDAS
#
# •	Pandas is an open-source Python Library providing high-performance data manipulation and analysis tool using its powerful data structures.
#
# •	In 2008, developer Wes McKinney started developing pandas when in need of high performance, flexible tool for analysis of data.
#
# •	Initial release	11 January 2008
#
# •	Using Pandas, we can accomplish five typical steps in the processing and analysis of data, regardless of the origin of data — load, prepare, manipulate, model, and analyze.
#
# ## Key Features of Pandas
# •	Fast and efficient DataFrame object with default and customized indexing.
#
# •	Tools for loading data into in-memory data objects from different file formats.(CSV,XLSX,JSON,XML,HTML,pytabes,SQL,SAS)
#
# •	Data alignment and integrated handling of missing data.
#
# •	Reshaping and pivoting of date sets.
#
# •	Label-based slicing, indexing and subsetting of large data sets.
#
# •	Columns from a data structure can be deleted or inserted.
#
# •	Group by data for aggregation and transformations.
#
# •	High performance merging and joining of data.
#
# •	Time Series functionality.

# %% [markdown]
# ## Installation Instructions
#     pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # Series

# %% [markdown]
# A Series is very similar to a NumPy array (in fact it is built on top of the NumPy array object). What differentiates the NumPy array from a Series, is that a Series can have axis labels, meaning it can be indexed by a label, instead of just a number location. It also doesn't need to hold numeric data, it can hold any arbitrary Python Object.

# %% [markdown]
# ### Creating a Series
#
# converting a list,  numpy array or dictionary to a Series:

# %%
ll = ('ag','bh','cd')
my_list = [2,3,4]

d = {'name':'R' , 'age':2, 'class':30}

# %%
print( pd.Series( data = ll ) )
# Out:
# 0    ag
# 1    bh
# 2    cd
# dtype: object

# %%
pd.Series(data = my_list , index = ll)  # recommended
# Out:
# ag    2
# bh    3
# cd    4
# dtype: int64

# %%
pd.Series(d)
# Out:
# name      R
# age       2
# class    30
# dtype: object

# %%
ser1 = pd.Series(data = [10,20,30,40,50,60,70] , index = ['a' , 'b', 'c' , 'd','e','f','g'])

# %%
ser1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64

# %%
# retriveing data using label index
ser1['a']
# Out:
# np.int64(10)

# %%
# can also work with numerical index like list , string, tuple
ser1[0]
# Out:
# /tmp/ipykernel_1840828/3125005978.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ser1[0]
# np.int64(10)

# %%
#retrieve the first three element
# ser1[:3]    
ser1[:'c']
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser2 = pd.Series(data = [10,20,50,40,50,60,70] , index = ['a', 'b' ,'cde', 'd' , 'e' , 'f','g'])

# %%
ser2
# Out:
# a      10
# b      20
# cde    50
# d      40
# e      50
# f      60
# g      70
# dtype: int64

# %%
ser1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64

# %%
ser1 + ser2
# Out:
# a       20.0
# b       40.0
# c        NaN
# cde      NaN
# d       80.0
# e      100.0
# f      120.0
# g      140.0
# dtype: float64

# %%
ser1.head(2)
# Out:
# a    10
# b    20
# dtype: int64

# %%
ser1.tail(3)
# Out:
# e    50
# f    60
# g    70
# dtype: int64

# %%
ser1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64

# %%
ser1.ndim
# Out:
# 1

# %%
ser1.shape
# Out:
# (7,)

# %%
type(ser1)
# Out:
# pandas.core.series.Series

# %%
len(ser1)
# Out:
# 7

# %% [markdown]
# # DataFrames
#
# •	DataFrames are directly inspired by the R programming language.
# We can think of a DataFrame as a bunch of Series objects put together to share the same index.
#
# •  It is two-dimensional(2-D) data structure which consists of rows and columns.
#
# #### Features of DataFrame
# •	Potentially columns are of different types
#
# •	Size – Mutable
#
# •	Labeled axes (rows and columns)
#
# •	Can Perform Arithmetic operations on rows and columns
#
# #### Syntax
#        pd.DataFrame(data, index, columns, dtype)
#
#        here ,data can be dictionaries , Series , 2D-numpy Ndarray , lists

# %%
dict1 = {'Name'   : ['aa','bb','cc'] ,
         'age'    : [40,50,60] , 
         'course' : ['DS','ML','DL'] ,
         'day'    : [10 , 11 , 12 ] } 

df = pd.DataFrame(data = dict1) 
df
# Out:
#   Name  age course  day
# 0   aa   40     DS   10
# 1   bb   50     ML   11
# 2   cc   60     DL   12

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# pd.read_  # tab

# %%
# ensure you pass the file extension while reading the data
# you pass the complete path of the file if it is not present in the same folder where this code is present

df = pd.read_csv('data/tips.csv')

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.ndim  # for checking dimensions
# Out:
# 2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.head(1)
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
df.tail(1)
# Out:
#      total_bill  tip  gender smoker   day    time  size
# 243       18.78  3.0  Female     No  Thur  Dinner     2

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# gender         object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   gender      244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.memory_usage() # in bytes
# Out:
# Index          132
# total_bill    1952
# tip           1952
# gender        1952
# smoker        1952
# day           1952
# time          1952
# size          1952
# dtype: int64

# %%
df.values  # converts whole pandas dataframe into numpy array
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]],
#       shape=(244, 7), dtype=object)

# %%
df.describe()  # despcriptive info
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
list(df.columns)
# Out:
# ['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['tip']
# df.tip # not recommended
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
type(df['tip'])
# Out:
# pandas.core.series.Series

# %%
df[  ['tip','gender','smoker']   ]
# Out:
#       tip  gender smoker
# 0    1.01  Female     No
# 1    1.66    Male     No
# 2    3.50    Male     No
# 3    3.31    Male     No
# 4    3.61  Female     No
# ..    ...     ...    ...
# 239  5.92    Male     No
# 240  2.00  Female    Yes
# 241  2.00    Male    Yes
# 242  1.75    Male     No
# 243  3.00  Female     No
#
# [244 rows x 3 columns]

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['gender'].unique()  # gives us all the unique/distinct values present in this column
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['gender'].nunique()
# Out:
# 2

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].value_counts(normalize = True)  # / len(df) -> 244
# Out:
# day
# Sat     0.356557
# Sun     0.311475
# Thur    0.254098
# Fri     0.077869
# Name: proportion, dtype: float64

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['percent_tip_wrt_total_bill']   =   1

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ..                          ...
# 239                           1
# 240                           1
# 241                           1
# 242                           1
# 243                           1
#
# [244 rows x 8 columns]

# %%
df['tip']  /  df['total_bill']
# Out:
# 0      0.059447
# 1      0.160542
# 2      0.166587
# 3      0.139780
# 4      0.146808
#          ...
# 239    0.203927
# 240    0.073584
# 241    0.088222
# 242    0.098204
# 243    0.159744
# Length: 244, dtype: float64

# %%
df['percent_tip_wrt_total_bill'] =  (  (df['tip']  /  df['total_bill']) * 100  ).round(2)

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                          5.94
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 4                         14.68
# ..                          ...
# 239                       20.39
# 240                        7.36
# 241                        8.82
# 242                        9.82
# 243                       15.97
#
# [244 rows x 8 columns]

# %%
df.dtypes
# Out:
# total_bill                    float64
# tip                           float64
# gender                         object
# smoker                         object
# day                            object
# time                           object
# size                            int64
# percent_tip_wrt_total_bill    float64
# dtype: object

# %%
# df['gender'] = 1    # overwrites the values in columns

# %%
# df.drop(columns = ['percent_tip_wrt_total_bill',]) 
df.drop('percent_tip_wrt_total_bill' , axis = 1)
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                          5.94
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 4                         14.68
# ..                          ...
# 239                       20.39
# 240                        7.36
# 241                        8.82
# 242                        9.82
# 243                       15.97
#
# [244 rows x 8 columns]

# %%
df.drop('percent_tip_wrt_total_bill' , axis = 1 , inplace = True)

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.drop(['smoker' , 'gender'] , axis = 1) # use list to drop multiple cols
# Out:
#      total_bill   tip   day    time  size
# 0         16.99  1.01   Sun  Dinner     2
# 1         10.34  1.66   Sun  Dinner     3
# 2         21.01  3.50   Sun  Dinner     3
# 3         23.68  3.31   Sun  Dinner     2
# 4         24.59  3.61   Sun  Dinner     4
# ..          ...   ...   ...     ...   ...
# 239       29.03  5.92   Sat  Dinner     3
# 240       27.18  2.00   Sat  Dinner     2
# 241       22.67  2.00   Sat  Dinner     2
# 242       17.82  1.75   Sat  Dinner     2
# 243       18.78  3.00  Thur  Dinner     2
#
# [244 rows x 5 columns]

# %%
df.drop(4 , axis = 0)
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.drop([1,2,3,4,5,6])
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [238 rows x 7 columns]

# %%
df['percent_tip_wrt_total_bill'] =  ((df['tip']  /  df['total_bill']) * 100).round(2)

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                          5.94
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 4                         14.68
# ..                          ...
# 239                       20.39
# 240                        7.36
# 241                        8.82
# 242                        9.82
# 243                       15.97
#
# [244 rows x 8 columns]

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    percent_tip_wrt_total_bill
# 0                        5.94
# 1                       16.05
# 2                       16.66
# 3                       13.98
# 4                       14.68

# %%
df.loc[ [1,4] , ['smoker','time'] ]  # df.loc[ rows , columns ]
# Out:
#   smoker    time
# 1     No  Dinner
# 4     No  Dinner

# %%
# .loc function can be used to select multiple rows and columns or even a single value

df.loc[ 1 , 'smoker' ]  # df.loc[ rows , columns ]
# Out:
# 'No'

# %%
# also uesd for selecting data but can only select a single value

df.at[1 , 'smoker']
# Out:
# 'No'

# %%
df.loc[ 4:18 , ['smoker','day'] ]
# Out:
#    smoker  day
# 4      No  Sun
# 5      No  Sun
# 6      No  Sun
# 7      No  Sun
# 8      No  Sun
# 9      No  Sun
# 10     No  Sun
# 11     No  Sun
# 12     No  Sun
# 13     No  Sun
# 14     No  Sun
# 15     No  Sun
# 16     No  Sun
# 17     No  Sun
# 18     No  Sun

# %%
df.loc[ 4:18 , : ]
# Out:
#     total_bill   tip  gender smoker  day    time  size  \
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3
# 17       16.29  3.71    Male     No  Sun  Dinner     3
# 18       16.97  3.50  Female     No  Sun  Dinner     3
#
#     percent_tip_wrt_total_bill
# 4                        14.68
# 5                        18.62
# 6                        22.81
# 7                        11.61
# 8                        13.03
# 9                        21.85
# 10                       16.65
# 11                       14.18
# 12                       10.18
# 13                       16.28
# 14                       20.36
# 15                       18.16
# 16                       16.17
# 17                       22.77
# 18                       20.62

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                          5.94
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 4                         14.68
# ..                          ...
# 239                       20.39
# 240                        7.36
# 241                        8.82
# 242                        9.82
# 243                       15.97
#
# [244 rows x 8 columns]

# %%
df.iloc[ [0,4] , [3,5]  ]
# Out:
#   smoker    time
# 0     No  Dinner
# 4     No  Dinner

# %%
df.iloc[:6 , 5:]
# Out:
#      time  size  percent_tip_wrt_total_bill
# 0  Dinner     2                        5.94
# 1  Dinner     3                       16.05
# 2  Dinner     3                       16.66
# 3  Dinner     2                       13.98
# 4  Dinner     4                       14.68
# 5  Dinner     4                       18.62

# %%
# .iloc function can be used to select multiple rows and columns or even a single value

df.iloc[3 , 5]
# Out:
# 'Dinner'

# %%
# also uesd for selecting data but can only select a single value

df.iat[3 , 5]
# Out:
# 'Dinner'

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                          5.94
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 4                         14.68
# ..                          ...
# 239                       20.39
# 240                        7.36
# 241                        8.82
# 242                        9.82
# 243                       15.97
#
# [244 rows x 8 columns]

# %%
df[['total_bill', 'tip', 'size']].mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
df['total_bill'].mean()
# Out:
# np.float64(19.78594262295082)

# %%
df['total_bill'].median()
# Out:
# 17.795

# %%
df['total_bill'].sum()
# Out:
# np.float64(4827.77)

# %%
df['total_bill'].std()
# Out:
# 8.902411954856856

# %%
df['total_bill'].cumsum()
# Out:
# 0        16.99
# 1        27.33
# 2        48.34
# 3        72.02
# 4        96.61
#         ...
# 239    4741.32
# 240    4768.50
# 241    4791.17
# 242    4808.99
# 243    4827.77
# Name: total_bill, Length: 244, dtype: float64

# %%
# df['total_bill'].   # press tab gives you all the possible functions

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                          5.94
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 4                         14.68
# ..                          ...
# 239                       20.39
# 240                        7.36
# 241                        8.82
# 242                        9.82
# 243                       15.97
#
# [244 rows x 8 columns]

# %%
df['gender'] == 'Male'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 239     True
# 240    False
# 241     True
# 242     True
# 243    False
# Name: gender, Length: 244, dtype: bool

# %%
df[   df['gender'] == "Male"    ]
# Out:
#      total_bill   tip gender smoker  day    time  size  \
# 1         10.34  1.66   Male     No  Sun  Dinner     3
# 2         21.01  3.50   Male     No  Sun  Dinner     3
# 3         23.68  3.31   Male     No  Sun  Dinner     2
# 5         25.29  4.71   Male     No  Sun  Dinner     4
# 6          8.77  2.00   Male     No  Sun  Dinner     2
# ..          ...   ...    ...    ...  ...     ...   ...
# 236       12.60  1.00   Male    Yes  Sat  Dinner     2
# 237       32.83  1.17   Male    Yes  Sat  Dinner     2
# 239       29.03  5.92   Male     No  Sat  Dinner     3
# 241       22.67  2.00   Male    Yes  Sat  Dinner     2
# 242       17.82  1.75   Male     No  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 5                         18.62
# 6                         22.81
# ..                          ...
# 236                        7.94
# 237                        3.56
# 239                       20.39
# 241                        8.82
# 242                        9.82
#
# [157 rows x 8 columns]

# %%
male_df = df[df['gender'] == "Male"]

# %%
male_df
# Out:
#      total_bill   tip gender smoker  day    time  size  \
# 1         10.34  1.66   Male     No  Sun  Dinner     3
# 2         21.01  3.50   Male     No  Sun  Dinner     3
# 3         23.68  3.31   Male     No  Sun  Dinner     2
# 5         25.29  4.71   Male     No  Sun  Dinner     4
# 6          8.77  2.00   Male     No  Sun  Dinner     2
# ..          ...   ...    ...    ...  ...     ...   ...
# 236       12.60  1.00   Male    Yes  Sat  Dinner     2
# 237       32.83  1.17   Male    Yes  Sat  Dinner     2
# 239       29.03  5.92   Male     No  Sat  Dinner     3
# 241       22.67  2.00   Male    Yes  Sat  Dinner     2
# 242       17.82  1.75   Male     No  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 5                         18.62
# 6                         22.81
# ..                          ...
# 236                        7.94
# 237                        3.56
# 239                       20.39
# 241                        8.82
# 242                        9.82
#
# [157 rows x 8 columns]

# %%
df[df['gender'] == "Male"][['total_bill','percent_tip_wrt_total_bill']].head(5).nunique()
# Out:
# total_bill                    5
# percent_tip_wrt_total_bill    5
# dtype: int64

# %%
df [  (df['gender'] == 'Male')  &  ( df['smoker'] == 'No')  ] # & = and
# Out:
#      total_bill   tip gender smoker  day    time  size  \
# 1         10.34  1.66   Male     No  Sun  Dinner     3
# 2         21.01  3.50   Male     No  Sun  Dinner     3
# 3         23.68  3.31   Male     No  Sun  Dinner     2
# 5         25.29  4.71   Male     No  Sun  Dinner     4
# 6          8.77  2.00   Male     No  Sun  Dinner     2
# ..          ...   ...    ...    ...  ...     ...   ...
# 232       11.61  3.39   Male     No  Sat  Dinner     2
# 233       10.77  1.47   Male     No  Sat  Dinner     2
# 235       10.07  1.25   Male     No  Sat  Dinner     2
# 239       29.03  5.92   Male     No  Sat  Dinner     3
# 242       17.82  1.75   Male     No  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 5                         18.62
# 6                         22.81
# ..                          ...
# 232                       29.20
# 233                       13.65
# 235                       12.41
# 239                       20.39
# 242                        9.82
#
# [97 rows x 8 columns]

# %%
df [  (df['gender'] == 'Male')  & 
      ( df['smoker'] == 'No')   & 
      ( df['total_bill'] > 15 ) ]
# Out:
#      total_bill   tip gender smoker  day    time  size  \
# 2         21.01  3.50   Male     No  Sun  Dinner     3
# 3         23.68  3.31   Male     No  Sun  Dinner     2
# 5         25.29  4.71   Male     No  Sun  Dinner     4
# 7         26.88  3.12   Male     No  Sun  Dinner     4
# 8         15.04  1.96   Male     No  Sun  Dinner     2
# ..          ...   ...    ...    ...  ...     ...   ...
# 185       20.69  5.00   Male     No  Sun  Dinner     5
# 212       48.33  9.00   Male     No  Sat  Dinner     4
# 227       20.45  3.00   Male     No  Sat  Dinner     4
# 239       29.03  5.92   Male     No  Sat  Dinner     3
# 242       17.82  1.75   Male     No  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 2                         16.66
# 3                         13.98
# 5                         18.62
# 7                         11.61
# 8                         13.03
# ..                          ...
# 185                       24.17
# 212                       18.62
# 227                       14.67
# 239                       20.39
# 242                        9.82
#
# [67 rows x 8 columns]

# %%
df [  (df['gender'] == 'Male')  |  ( df['smoker'] == 'Yes')  ] # | = or
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 6          8.77  2.00    Male     No  Sun  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 5                         18.62
# 6                         22.81
# ..                          ...
# 237                        3.56
# 239                       20.39
# 240                        7.36
# 241                        8.82
# 242                        9.82
#
# [190 rows x 8 columns]

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                          5.94
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 4                         14.68
# ..                          ...
# 239                       20.39
# 240                        7.36
# 241                        8.82
# 242                        9.82
# 243                       15.97
#
# [244 rows x 8 columns]

# %%
df.sort_values(by = 'percent_tip_wrt_total_bill' , ascending = False , inplace = True)

# %%
df
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 232       11.61  3.39    Male     No  Sat  Dinner     2
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 57        26.41  1.50  Female     No  Sat  Dinner     2
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 172                       71.03
# 178                       41.67
# 67                        32.57
# 232                       29.20
# 183                       28.05
# ..                          ...
# 187                        6.57
# 0                          5.94
# 57                         5.68
# 102                        5.64
# 237                        3.56
#
# [244 rows x 8 columns]

# %%
df.sort_values(by = ['percent_tip_wrt_total_bill' , 'tip'] , ascending = [False, True])
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 232       11.61  3.39    Male     No  Sat  Dinner     2
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 57        26.41  1.50  Female     No  Sat  Dinner     2
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 172                       71.03
# 178                       41.67
# 67                        32.57
# 232                       29.20
# 183                       28.05
# ..                          ...
# 187                        6.57
# 0                          5.94
# 57                         5.68
# 102                        5.64
# 237                        3.56
#
# [244 rows x 8 columns]

# %%
df.sort_index()
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                          5.94
# 1                         16.05
# 2                         16.66
# 3                         13.98
# 4                         14.68
# ..                          ...
# 239                       20.39
# 240                        7.36
# 241                        8.82
# 242                        9.82
# 243                       15.97
#
# [244 rows x 8 columns]

# %%
df.index
# Out:
# Index([172, 178,  67, 232, 183, 109, 149,  93, 221,  51,
#        ...
#        184, 240, 146,  48, 210, 187,   0,  57, 102, 237],
#       dtype='int64', length=244)

# %%
df.reset_index()
# Out:
#      index  total_bill   tip  gender smoker  day    time  size  \
# 0      172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 1      178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 2       67        3.07  1.00  Female    Yes  Sat  Dinner     1
# 3      232       11.61  3.39    Male     No  Sat  Dinner     2
# 4      183       23.17  6.50    Male    Yes  Sun  Dinner     4
# ..     ...         ...   ...     ...    ...  ...     ...   ...
# 239    187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 240      0       16.99  1.01  Female     No  Sun  Dinner     2
# 241     57       26.41  1.50  Female     No  Sat  Dinner     2
# 242    102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 243    237       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                         71.03
# 1                         41.67
# 2                         32.57
# 3                         29.20
# 4                         28.05
# ..                          ...
# 239                        6.57
# 240                        5.94
# 241                        5.68
# 242                        5.64
# 243                        3.56
#
# [244 rows x 9 columns]

# %%
df
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1
# 232       11.61  3.39    Male     No  Sat  Dinner     2
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 57        26.41  1.50  Female     No  Sat  Dinner     2
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 172                       71.03
# 178                       41.67
# 67                        32.57
# 232                       29.20
# 183                       28.05
# ..                          ...
# 187                        6.57
# 0                          5.94
# 57                         5.68
# 102                        5.64
# 237                        3.56
#
# [244 rows x 8 columns]

# %%
df.reset_index(drop = True , inplace = True)

# %%
df
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 0          7.25  5.15    Male    Yes  Sun  Dinner     2
# 1          9.60  4.00  Female    Yes  Sun  Dinner     2
# 2          3.07  1.00  Female    Yes  Sat  Dinner     1
# 3         11.61  3.39    Male     No  Sat  Dinner     2
# 4         23.17  6.50    Male    Yes  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 239       30.46  2.00    Male    Yes  Sun  Dinner     5
# 240       16.99  1.01  Female     No  Sun  Dinner     2
# 241       26.41  1.50  Female     No  Sat  Dinner     2
# 242       44.30  2.50  Female    Yes  Sat  Dinner     3
# 243       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                         71.03
# 1                         41.67
# 2                         32.57
# 3                         29.20
# 4                         28.05
# ..                          ...
# 239                        6.57
# 240                        5.94
# 241                        5.68
# 242                        5.64
# 243                        3.56
#
# [244 rows x 8 columns]

# %%
pd.options.display.max_rows = 30
pd.options.display.max_columns = 100

# %%
df
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 0          7.25  5.15    Male    Yes  Sun  Dinner     2
# 1          9.60  4.00  Female    Yes  Sun  Dinner     2
# 2          3.07  1.00  Female    Yes  Sat  Dinner     1
# 3         11.61  3.39    Male     No  Sat  Dinner     2
# 4         23.17  6.50    Male    Yes  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 239       30.46  2.00    Male    Yes  Sun  Dinner     5
# 240       16.99  1.01  Female     No  Sun  Dinner     2
# 241       26.41  1.50  Female     No  Sat  Dinner     2
# 242       44.30  2.50  Female    Yes  Sat  Dinner     3
# 243       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                         71.03
# 1                         41.67
# 2                         32.57
# 3                         29.20
# 4                         28.05
# ..                          ...
# 239                        6.57
# 240                        5.94
# 241                        5.68
# 242                        5.64
# 243                        3.56
#
# [244 rows x 8 columns]

# %%
df.isna()
# Out:
#      total_bill    tip  gender  smoker    day   time   size  \
# 0         False  False   False   False  False  False  False
# 1         False  False   False   False  False  False  False
# 2         False  False   False   False  False  False  False
# 3         False  False   False   False  False  False  False
# 4         False  False   False   False  False  False  False
# ..          ...    ...     ...     ...    ...    ...    ...
# 239       False  False   False   False  False  False  False
# 240       False  False   False   False  False  False  False
# 241       False  False   False   False  False  False  False
# 242       False  False   False   False  False  False  False
# 243       False  False   False   False  False  False  False
#
#      percent_tip_wrt_total_bill
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ..                          ...
# 239                       False
# 240                       False
# 241                       False
# 242                       False
# 243                       False
#
# [244 rows x 8 columns]

# %%
False + False + False + True   # False = 0 , True = 1   # 0 + 0 + 0 + 1
# Out:
# 1

# %%
df.isna().sum()    # False = 0 , True = 1
# Out:
# total_bill                    0
# tip                           0
# gender                        0
# smoker                        0
# day                           0
# time                          0
# size                          0
# percent_tip_wrt_total_bill    0
# dtype: int64

# %%
# None , np.nan ---> null values
null_df = pd.DataFrame(data = {'A' : [10,3,None],   'B' : [9, None, None], 'C' : [15, 20, 35] })

# %%
null_df
# Out:
#       A    B   C
# 0  10.0  9.0  15
# 1   3.0  NaN  20
# 2   NaN  NaN  35

# %%
null_df.isna()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
null_df.isna().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
null_df
# Out:
#       A    B   C
# 0  10.0  9.0  15
# 1   3.0  NaN  20
# 2   NaN  NaN  35

# %%
null_df.dropna()
# Out:
#       A    B   C
# 0  10.0  9.0  15

# %%
null_df.dropna(thresh = 2)
# Out:
#       A    B   C
# 0  10.0  9.0  15
# 1   3.0  NaN  20

# %%
null_df
# Out:
#       A    B   C
# 0  10.0  9.0  15
# 1   3.0  NaN  20
# 2   NaN  NaN  35

# %%
# null_df.dropna(inplace = True)

# %%
null_df.fillna('any value which can be used to fill')
# Out:
#                                      A                                    B  \
# 0                                 10.0                                  9.0
# 1                                  3.0  any value which can be used to fill
# 2  any value which can be used to fill  any value which can be used to fill
#
#     C
# 0  15
# 1  20
# 2  35

# %%
null_df
# Out:
#       A    B   C
# 0  10.0  9.0  15
# 1   3.0  NaN  20
# 2   NaN  NaN  35

# %%
null_df['A'].mean()
# Out:
# np.float64(6.5)

# %%
a_mean = null_df['A'].mean()

# %%
null_df.fillna( {'A' : a_mean} )
# Out:
#       A    B   C
# 0  10.0  9.0  15
# 1   3.0  NaN  20
# 2   6.5  NaN  35

# %%
null_df
# Out:
#       A    B   C
# 0  10.0  9.0  15
# 1   3.0  NaN  20
# 2   NaN  NaN  35

# %%
null_df.fillna(method = 'ffill') # forward fill techq  
# this warning mentions that in future it will not work with wholde df, instead on individual columns
# Out:
# /tmp/ipykernel_1840828/2090384732.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   null_df.fillna(method = 'ffill') # forward fill techq
#       A    B   C
# 0  10.0  9.0  15
# 1   3.0  9.0  20
# 2   3.0  9.0  35

# %%
null_df.fillna( {'A' : a_mean}, inplace = True  )

# %%
null_df
# Out:
#       A    B   C
# 0  10.0  9.0  15
# 1   3.0  NaN  20
# 2   6.5  NaN  35

# %%
df
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 0          7.25  5.15    Male    Yes  Sun  Dinner     2
# 1          9.60  4.00  Female    Yes  Sun  Dinner     2
# 2          3.07  1.00  Female    Yes  Sat  Dinner     1
# 3         11.61  3.39    Male     No  Sat  Dinner     2
# 4         23.17  6.50    Male    Yes  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 239       30.46  2.00    Male    Yes  Sun  Dinner     5
# 240       16.99  1.01  Female     No  Sun  Dinner     2
# 241       26.41  1.50  Female     No  Sat  Dinner     2
# 242       44.30  2.50  Female    Yes  Sat  Dinner     3
# 243       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                         71.03
# 1                         41.67
# 2                         32.57
# 3                         29.20
# 4                         28.05
# ..                          ...
# 239                        6.57
# 240                        5.94
# 241                        5.68
# 242                        5.64
# 243                        3.56
#
# [244 rows x 8 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[  df.duplicated()  ]
# Out:
#      total_bill  tip  gender smoker   day   time  size  \
# 124        13.0  2.0  Female    Yes  Thur  Lunch     2
#
#      percent_tip_wrt_total_bill
# 124                       15.38

# %%
df.duplicated(keep = False).sum()
# Out:
# np.int64(2)

# %%
df[  df.duplicated(keep = False)  ]  # simply labels both the occurences as duplicates
# Out:
#      total_bill  tip  gender smoker   day   time  size  \
# 123        13.0  2.0  Female    Yes  Thur  Lunch     2
# 124        13.0  2.0  Female    Yes  Thur  Lunch     2
#
#      percent_tip_wrt_total_bill
# 123                       15.38
# 124                       15.38

# %%
df[['gender', 'smoker']]
# Out:
#      gender smoker
# 0      Male    Yes
# 1    Female    Yes
# 2    Female    Yes
# 3      Male     No
# 4      Male    Yes
# ..      ...    ...
# 239    Male    Yes
# 240  Female     No
# 241  Female     No
# 242  Female    Yes
# 243    Male    Yes
#
# [244 rows x 2 columns]

# %%
df.duplicated(subset = ['gender', 'smoker']).sum()  # df[['gender','day']].duplicated().sum()
# Out:
# np.int64(240)

# %%
df.drop_duplicates(keep = 'first' , inplace = True)

# %%
df
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 0          7.25  5.15    Male    Yes  Sun  Dinner     2
# 1          9.60  4.00  Female    Yes  Sun  Dinner     2
# 2          3.07  1.00  Female    Yes  Sat  Dinner     1
# 3         11.61  3.39    Male     No  Sat  Dinner     2
# 4         23.17  6.50    Male    Yes  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 239       30.46  2.00    Male    Yes  Sun  Dinner     5
# 240       16.99  1.01  Female     No  Sun  Dinner     2
# 241       26.41  1.50  Female     No  Sat  Dinner     2
# 242       44.30  2.50  Female    Yes  Sat  Dinner     3
# 243       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                         71.03
# 1                         41.67
# 2                         32.57
# 3                         29.20
# 4                         28.05
# ..                          ...
# 239                        6.57
# 240                        5.94
# 241                        5.68
# 242                        5.64
# 243                        3.56
#
# [243 rows x 8 columns]

# %%
df.T
# Out:
#                                0       1       2       3       4       5    \
# total_bill                    7.25     9.6    3.07   11.61   23.17   14.31
# tip                           5.15     4.0     1.0    3.39     6.5     4.0
# gender                        Male  Female  Female    Male    Male  Female
# smoker                         Yes     Yes     Yes      No     Yes     Yes
# day                            Sun     Sun     Sat     Sat     Sun     Sat
# time                        Dinner  Dinner  Dinner  Dinner  Dinner  Dinner
# size                             2       2       1       2       4       2
# percent_tip_wrt_total_bill   71.03   41.67   32.57    29.2   28.05   27.95
#
#                               6       7       8       9       10      11   \
# total_bill                   7.51   16.32   13.42   10.29   23.33   20.69
# tip                           2.0     4.3    3.48     2.6    5.65     5.0
# gender                       Male  Female  Female  Female    Male    Male
# smoker                         No     Yes     Yes      No     Yes      No
# day                          Thur     Fri     Fri     Sun     Sun     Sun
# time                        Lunch  Dinner   Lunch  Dinner  Dinner  Dinner
# size                            2       2       2       2       2       5
# percent_tip_wrt_total_bill  26.63   26.35   25.93   25.27   24.22   24.17
#
#                               12      13     14      15      16      17   \
# total_bill                  16.58   16.82  24.71   28.17    8.77   17.92
# tip                           4.0     4.0   5.85     6.5     2.0    4.08
# gender                       Male    Male   Male  Female    Male    Male
# smoker                        Yes     Yes     No     Yes      No      No
# day                          Thur     Sun   Thur     Sat     Sun     Sat
# time                        Lunch  Dinner  Lunch  Dinner  Dinner  Dinner
# size                            2       2      2       3       2       2
# percent_tip_wrt_total_bill  24.13   23.78  23.67   23.07   22.81   22.77
#
#                                18      19     20      21      22     23   \
# total_bill                   16.29   22.23   8.58   11.35   13.94  18.28
# tip                           3.71     5.0   1.92     2.5    3.06    4.0
# gender                        Male    Male   Male  Female    Male   Male
# smoker                          No      No    Yes     Yes      No     No
# day                            Sun     Sun    Fri     Fri     Sun   Thur
# time                        Dinner  Dinner  Lunch  Dinner  Dinner  Lunch
# size                             3       2      1       2       2      2
# percent_tip_wrt_total_bill   22.77   22.49  22.38   22.03   21.95  21.88
#
#                                24      25     26      27      28      29   \
# total_bill                   14.78    14.0  18.71   19.81   13.16   16.97
# tip                           3.23     3.0    4.0    4.19    2.75     3.5
# gender                        Male    Male   Male  Female  Female  Female
# smoker                          No      No    Yes     Yes      No      No
# day                            Sun     Sat   Thur    Thur    Thur     Sun
# time                        Dinner  Dinner  Lunch   Lunch   Lunch  Dinner
# size                             2       2      3       2       2       3
# percent_tip_wrt_total_bill   21.85   21.43  21.38   21.15    20.9   20.62
#
#                                30      31      32     33      34      35   \
# total_bill                   18.24   18.29   13.28  16.66   29.03   14.83
# tip                           3.76    3.76    2.72    3.4    5.92    3.02
# gender                        Male    Male    Male   Male    Male  Female
# smoker                          No     Yes      No     No      No      No
# day                            Sat     Sat     Sat   Thur     Sat     Sun
# time                        Dinner  Dinner  Dinner  Lunch  Dinner  Dinner
# size                             2       4       2      2       3       2
# percent_tip_wrt_total_bill   20.61   20.56   20.48  20.41   20.39   20.36
#
#                                36      37      38      39      40      41   \
# total_bill                   17.31   12.48   17.47   15.81   12.54   25.89
# tip                            3.5    2.52     3.5    3.16     2.5    5.16
# gender                      Female  Female  Female    Male    Male    Male
# smoker                          No      No      No     Yes      No     Yes
# day                            Sun    Thur    Thur     Sat     Sun     Sat
# time                        Dinner   Lunch   Lunch  Dinner  Dinner  Dinner
# size                             2       2       2       2       2       4
# percent_tip_wrt_total_bill   20.22   20.19   20.03   19.99   19.94   19.93
#
#                                42      43      44      45      46     47   \
# total_bill                   15.06    21.7   10.09   20.49   25.28  11.69
# tip                            3.0     4.3     2.0    4.06     5.0   2.31
# gender                      Female    Male  Female    Male  Female   Male
# smoker                          No      No     Yes     Yes     Yes     No
# day                            Sat     Sat     Fri     Sat     Sat   Thur
# time                        Dinner  Dinner   Lunch  Dinner  Dinner  Lunch
# size                             2       2       2       2       2      2
# percent_tip_wrt_total_bill   19.92   19.82   19.82   19.81   19.78  19.76
#
#                                48      49   ...     194     195     196  \
# total_bill                   12.66   50.81  ...   16.49   24.08   12.46
# tip                            2.5    10.0  ...     2.0    2.92     1.5
# gender                        Male    Male  ...    Male  Female    Male
# smoker                          No     Yes  ...      No      No      No
# day                            Sun     Sat  ...     Sun    Thur     Fri
# time                        Dinner  Dinner  ...  Dinner   Lunch  Dinner
# size                             2       3  ...       4       4       2
# percent_tip_wrt_total_bill   19.75   19.68  ...   12.13   12.13   12.04
#
#                                197     198    199     200     201     202  \
# total_bill                   10.51   20.69  13.42   40.17   26.86   26.88
# tip                           1.25    2.45   1.58    4.73    3.14    3.12
# gender                        Male  Female   Male    Male  Female    Male
# smoker                          No      No    Yes     Yes     Yes      No
# day                            Sat     Sat    Fri     Fri     Sat     Sun
# time                        Dinner  Dinner  Lunch  Dinner  Dinner  Dinner
# size                             2       4      2       4       2       4
# percent_tip_wrt_total_bill   11.89   11.84  11.77   11.77   11.69   11.61
#
#                                203     204     205     206     207     208  \
# total_bill                   43.11   17.89   20.76   15.36   28.15   23.95
# tip                            5.0     2.0    2.24    1.64     3.0    2.55
# gender                      Female    Male    Male    Male    Male    Male
# smoker                         Yes     Yes      No     Yes     Yes      No
# day                           Thur     Sun     Sun     Sat     Sat     Sun
# time                         Lunch  Dinner  Dinner  Dinner  Dinner  Dinner
# size                             4       2       2       2       5       2
# percent_tip_wrt_total_bill    11.6   11.18   10.79   10.68   10.66   10.65
#
#                                209     210     211     212     213     214  \
# total_bill                   34.65   38.07   48.17   28.97   30.14   34.63
# tip                           3.68     4.0     5.0     3.0    3.09    3.55
# gender                        Male    Male    Male    Male  Female    Male
# smoker                         Yes      No      No     Yes     Yes     Yes
# day                            Sun     Sun     Sun     Fri     Sat     Sun
# time                        Dinner  Dinner  Dinner  Dinner  Dinner  Dinner
# size                             4       3       6       2       4       2
# percent_tip_wrt_total_bill   10.62   10.51   10.38   10.36   10.25   10.25
#
#                                215     216     217     218     219     220  \
# total_bill                   15.42   19.77   31.85   20.23   17.82   15.69
# tip                           1.57     2.0    3.18    2.01    1.75     1.5
# gender                        Male    Male    Male    Male    Male    Male
# smoker                          No      No     Yes      No      No     Yes
# day                            Sun     Sun     Sun     Sat     Sat     Sun
# time                        Dinner  Dinner  Dinner  Dinner  Dinner  Dinner
# size                             2       4       2       2       2       2
# percent_tip_wrt_total_bill   10.18   10.12    9.98    9.94    9.82    9.56
#
#                               221     222    223     224     225     226  \
# total_bill                  22.82    32.9  28.44   22.67    12.9   24.27
# tip                          2.18    3.11   2.56     2.0     1.1    2.03
# gender                       Male    Male   Male    Male  Female    Male
# smoker                         No     Yes    Yes     Yes     Yes     Yes
# day                          Thur     Sun   Thur     Sat     Sat     Sat
# time                        Lunch  Dinner  Lunch  Dinner  Dinner  Dinner
# size                            3       2      2       2       2       2
# percent_tip_wrt_total_bill   9.55    9.45    9.0    8.82    8.53    8.36
#
#                                227     228     229     230    231     232  \
# total_bill                   24.01   24.55    12.6   38.01  19.08   38.73
# tip                            2.0     2.0     1.0     3.0    1.5     3.0
# gender                        Male    Male    Male    Male   Male    Male
# smoker                         Yes      No     Yes     Yes     No     Yes
# day                            Sat     Sun     Sat     Sat   Thur     Sat
# time                        Dinner  Dinner  Dinner  Dinner  Lunch  Dinner
# size                             4       4       2       4      2       4
# percent_tip_wrt_total_bill    8.33    8.15    7.94    7.89   7.86    7.75
#
#                                233     234     235     236     237     238  \
# total_bill                   45.35   40.55   27.18   18.64   28.55   30.06
# tip                            3.5     3.0     2.0    1.36    2.05     2.0
# gender                        Male    Male  Female  Female    Male    Male
# smoker                         Yes     Yes     Yes      No      No     Yes
# day                            Sun     Sun     Sat    Thur     Sun     Sat
# time                        Dinner  Dinner  Dinner   Lunch  Dinner  Dinner
# size                             3       2       2       3       3       3
# percent_tip_wrt_total_bill    7.72     7.4    7.36     7.3    7.18    6.65
#
#                                239     240     241     242     243
# total_bill                   30.46   16.99   26.41    44.3   32.83
# tip                            2.0    1.01     1.5     2.5    1.17
# gender                        Male  Female  Female  Female    Male
# smoker                         Yes      No      No     Yes     Yes
# day                            Sun     Sun     Sat     Sat     Sat
# time                        Dinner  Dinner  Dinner  Dinner  Dinner
# size                             5       2       2       3       2
# percent_tip_wrt_total_bill    6.57    5.94    5.68    5.64    3.56
#
# [8 rows x 243 columns]

# %%
df
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 0          7.25  5.15    Male    Yes  Sun  Dinner     2
# 1          9.60  4.00  Female    Yes  Sun  Dinner     2
# 2          3.07  1.00  Female    Yes  Sat  Dinner     1
# 3         11.61  3.39    Male     No  Sat  Dinner     2
# 4         23.17  6.50    Male    Yes  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 239       30.46  2.00    Male    Yes  Sun  Dinner     5
# 240       16.99  1.01  Female     No  Sun  Dinner     2
# 241       26.41  1.50  Female     No  Sat  Dinner     2
# 242       44.30  2.50  Female    Yes  Sat  Dinner     3
# 243       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill
# 0                         71.03
# 1                         41.67
# 2                         32.57
# 3                         29.20
# 4                         28.05
# ..                          ...
# 239                        6.57
# 240                        5.94
# 241                        5.68
# 242                        5.64
# 243                        3.56
#
# [243 rows x 8 columns]

# %%
# used when data is categorical and cannot be ordered
pd.get_dummies(data  = df , columns = ['day'])  # one hot encoding
# Out:
#      total_bill   tip  gender smoker    time  size  \
# 0          7.25  5.15    Male    Yes  Dinner     2
# 1          9.60  4.00  Female    Yes  Dinner     2
# 2          3.07  1.00  Female    Yes  Dinner     1
# 3         11.61  3.39    Male     No  Dinner     2
# 4         23.17  6.50    Male    Yes  Dinner     4
# ..          ...   ...     ...    ...     ...   ...
# 239       30.46  2.00    Male    Yes  Dinner     5
# 240       16.99  1.01  Female     No  Dinner     2
# 241       26.41  1.50  Female     No  Dinner     2
# 242       44.30  2.50  Female    Yes  Dinner     3
# 243       32.83  1.17    Male    Yes  Dinner     2
#
#      percent_tip_wrt_total_bill  day_Fri  day_Sat  day_Sun  day_Thur
# 0                         71.03    False    False     True     False
# 1                         41.67    False    False     True     False
# 2                         32.57    False     True    False     False
# 3                         29.20    False     True    False     False
# 4                         28.05    False    False     True     False
# ..                          ...      ...      ...      ...       ...
# 239                        6.57    False    False     True     False
# 240                        5.94    False    False     True     False
# 241                        5.68    False     True    False     False
# 242                        5.64    False     True    False     False
# 243                        3.56    False     True    False     False
#
# [243 rows x 11 columns]

# %%
# used when data is categorical and cannot be ordered , 
# as only 3 columns are capable of giving complete info hence the first one is dropped using drop_first argument
pd.get_dummies(data  = df , columns = ['day'] , drop_first = True)  # one hot encoding
# Out:
#      total_bill   tip  gender smoker    time  size  \
# 0          7.25  5.15    Male    Yes  Dinner     2
# 1          9.60  4.00  Female    Yes  Dinner     2
# 2          3.07  1.00  Female    Yes  Dinner     1
# 3         11.61  3.39    Male     No  Dinner     2
# 4         23.17  6.50    Male    Yes  Dinner     4
# ..          ...   ...     ...    ...     ...   ...
# 239       30.46  2.00    Male    Yes  Dinner     5
# 240       16.99  1.01  Female     No  Dinner     2
# 241       26.41  1.50  Female     No  Dinner     2
# 242       44.30  2.50  Female    Yes  Dinner     3
# 243       32.83  1.17    Male    Yes  Dinner     2
#
#      percent_tip_wrt_total_bill  day_Sat  day_Sun  day_Thur
# 0                         71.03    False     True     False
# 1                         41.67    False     True     False
# 2                         32.57     True    False     False
# 3                         29.20     True    False     False
# 4                         28.05    False     True     False
# ..                          ...      ...      ...       ...
# 239                        6.57    False     True     False
# 240                        5.94    False     True     False
# 241                        5.68     True    False     False
# 242                        5.64     True    False     False
# 243                        3.56     True    False     False
#
# [243 rows x 10 columns]

# %%
df.groupby(['gender','time'])

# %%
grouped = df.groupby(['gender','time'])

# %%
grouped

# %%
grouped.groups
# Out:
# {('Female', 'Dinner'): [1, 2, 5, 7, 9, 15, 21, 29, 35, 36, 42, 46, 52, 53, 54, 59, 63, 64, 75, 84, 86, 87, 90, 92, 96, 106, 110, 120, 121, 128, 131, 133, 135, 138, 139, 144, 151, 156, 157, 168, 174, 180, 181, 191, 198, 201, 213, 225, 235, 240, 241, 242], ('Female', 'Lunch'): [8, 27, 28, 37, 38, 44, 50, 56, 65, 70, 73, 79, 80, 83, 102, 113, 123, 125, 129, 140, 143, 148, 158, 159, 160, 161, 164, 169, 170, 175, 186, 195, 203, 236], ('Male', 'Dinner'): [0, 3, 4, 10, 11, 13, 16, 17, 18, 19, 22, 24, 25, 30, 31, 32, 34, 39, 40, 41, 43, 45, 48, 49, 58, 60, 61, 66, 67, 68, 69, 71, 72, 74, 77, 78, 81, 89, 91, 93, 94, 95, 97, 98, 99, 100, 101, 103, 104, 105, 107, 108, 109, 111, 112, 114, 115, 116, 118, 119, 130, 132, 134, 136, 137, 145, 146, 147, 149, 150, 152, 153, 154, 162, 163, 165, 166, 167, 171, 172, 173, 177, 179, 182, 183, 188, 189, 190, 192, 194, 196, 197, 200, 202, 204, 205, 206, 207, 208, 209, ...], ('Male', 'Lunch'): [6, 12, 14, 20, 23, 26, 33, 47, 51, 55, 57, 62, 76, 82, 85, 88, 117, 122, 126, 127, 141, 142, 155, 176, 178, 184, 185, 187, 193, 199, 221, 223, 231]}

# %%
grouped.groups.keys()
# Out:
# dict_keys([('Female', 'Dinner'), ('Female', 'Lunch'), ('Male', 'Dinner'), ('Male', 'Lunch')])

# %%
grouped.get_group(('Female', 'Dinner'))
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 1          9.60  4.00  Female    Yes  Sun  Dinner     2
# 2          3.07  1.00  Female    Yes  Sat  Dinner     1
# 5         14.31  4.00  Female    Yes  Sat  Dinner     2
# 7         16.32  4.30  Female    Yes  Fri  Dinner     2
# 9         10.29  2.60  Female     No  Sun  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 225       12.90  1.10  Female    Yes  Sat  Dinner     2
# 235       27.18  2.00  Female    Yes  Sat  Dinner     2
# 240       16.99  1.01  Female     No  Sun  Dinner     2
# 241       26.41  1.50  Female     No  Sat  Dinner     2
# 242       44.30  2.50  Female    Yes  Sat  Dinner     3
#
#      percent_tip_wrt_total_bill
# 1                         41.67
# 2                         32.57
# 5                         27.95
# 7                         26.35
# 9                         25.27
# ..                          ...
# 225                        8.53
# 235                        7.36
# 240                        5.94
# 241                        5.68
# 242                        5.64
#
# [52 rows x 8 columns]

# %%
# for grp in grouped.groups.keys():
#     print(grouped.get_group(grp))
#     break

# %%
df[   (df['gender'] == 'Female')  &   (df['time'] == 'Dinner')]

# df[   (df['gender'] == 'Female')  &   (df['time'] == 'Dinner')].mean(numeric_only = True)
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 1          9.60  4.00  Female    Yes  Sun  Dinner     2
# 2          3.07  1.00  Female    Yes  Sat  Dinner     1
# 5         14.31  4.00  Female    Yes  Sat  Dinner     2
# 7         16.32  4.30  Female    Yes  Fri  Dinner     2
# 9         10.29  2.60  Female     No  Sun  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 225       12.90  1.10  Female    Yes  Sat  Dinner     2
# 235       27.18  2.00  Female    Yes  Sat  Dinner     2
# 240       16.99  1.01  Female     No  Sun  Dinner     2
# 241       26.41  1.50  Female     No  Sat  Dinner     2
# 242       44.30  2.50  Female    Yes  Sat  Dinner     3
#
#      percent_tip_wrt_total_bill
# 1                         41.67
# 2                         32.57
# 5                         27.95
# 7                         26.35
# 9                         25.27
# ..                          ...
# 225                        8.53
# 235                        7.36
# 240                        5.94
# 241                        5.68
# 242                        5.64
#
# [52 rows x 8 columns]

# %%
df.groupby(['gender','time'])

# %%
df.groupby(['gender','time']).mean(numeric_only = True)
# Out:
#                total_bill       tip      size  percent_tip_wrt_total_bill
# gender time
# Female Dinner   19.213077  3.002115  2.461538                   16.931731
#        Lunch    16.437353  2.600000  2.470588                   16.252059
# Male   Dinner   21.461452  3.144839  2.701613                   15.540403
#        Lunch    18.048485  2.882121  2.363636                   16.607576

# %%
df.groupby(by = ['gender','time','day']).mean(numeric_only = True).round(2)
# Out:
#                     total_bill   tip  size  percent_tip_wrt_total_bill
# gender time   day
# Female Dinner Fri        14.31  2.81  2.00                       19.91
#               Sat        19.68  2.80  2.25                       15.65
#               Sun        19.87  3.37  2.94                       18.16
#               Thur       18.78  3.00  2.00                       15.97
#        Lunch  Fri        13.94  2.74  2.25                       19.97
#               Thur       16.77  2.58  2.50                       15.76
# Male   Dinner Fri        23.49  3.03  2.29                       13.02
#               Sat        20.80  3.08  2.64                       15.16
#               Sun        21.89  3.22  2.81                       16.23
#        Lunch  Fri        11.39  1.90  1.67                       17.41
#               Thur       18.71  2.98  2.43                       16.53

# %%
df.groupby(by = ['gender','time','day']).mean(numeric_only = True).round(2)
# Out:
#                     total_bill   tip  size  percent_tip_wrt_total_bill
# gender time   day
# Female Dinner Fri        14.31  2.81  2.00                       19.91
#               Sat        19.68  2.80  2.25                       15.65
#               Sun        19.87  3.37  2.94                       18.16
#               Thur       18.78  3.00  2.00                       15.97
#        Lunch  Fri        13.94  2.74  2.25                       19.97
#               Thur       16.77  2.58  2.50                       15.76
# Male   Dinner Fri        23.49  3.03  2.29                       13.02
#               Sat        20.80  3.08  2.64                       15.16
#               Sun        21.89  3.22  2.81                       16.23
#        Lunch  Fri        11.39  1.90  1.67                       17.41
#               Thur       18.71  2.98  2.43                       16.53

# %%
df.groupby(by = ['day','time']).sum(True).round(2)
# Out:
#              total_bill     tip  size  percent_tip_wrt_total_bill
# day  time
# Fri  Dinner      235.96   35.28    26                      190.71
#      Lunch        89.92   16.68    14                      132.13
# Sat  Dinner     1778.40  260.40   219                     1332.37
# Sun  Dinner     1627.16  247.39   216                     1268.41
# Thur Dinner       18.78    3.00     2                       15.97
#      Lunch      1064.55  166.83   148                      968.49

# %%
df.groupby(['gender','time']).agg({'total_bill' : ['sum','min','max','count','mean'] ,
                                   'size' : ['sum',],
                                   'tip' : ['mean','min','max']})
# Out:
#               total_bill                               size       tip        \
#                      sum   min    max count       mean  sum      mean   min
# gender time
# Female Dinner     999.08  3.07  44.30    52  19.213077  128  3.002115  1.00
#        Lunch      558.87  8.35  43.11    34  16.437353   84  2.600000  1.25
# Male   Dinner    2661.22  7.25  50.81   124  21.461452  335  3.144839  1.00
#        Lunch      595.60  7.51  41.19    33  18.048485   78  2.882121  1.44
#
#
#                  max
# gender time
# Female Dinner   6.50
#        Lunch    5.17
# Male   Dinner  10.00
#        Lunch    6.70

# %%
grp = df.groupby(['gender','day', 'smoker'] ).mean(numeric_only = True)[['total_bill','tip']]
grp
# Out:
#                     total_bill       tip
# gender day  smoker
# Female Fri  No       19.365000  3.125000
#             Yes      12.654286  2.682857
#        Sat  No       19.003846  2.724615
#             Yes      20.266667  2.868667
#        Sun  No       20.824286  3.329286
#             Yes      16.540000  3.500000
#        Thur No       16.014400  2.459600
#             Yes      20.255000  3.155000
# Male   Fri  No       17.475000  2.500000
#             Yes      20.452500  2.741250
#        Sat  No       19.929063  3.256562
#             Yes      21.837778  2.879259
#        Sun  No       20.403256  3.115349
#             Yes      26.141333  3.521333
#        Thur No       18.486500  2.941500
#             Yes      19.171000  3.058000

# %%
df.groupby(['gender','time']).agg(lambda x  : set(x))  # you can have your own aggregations
# Out:
#                                                       total_bill  \
# gender time
# Female Dinner  {3.07, 26.86, 5.75, 26.41, 7.25, 27.18, 9.6, 1...
#        Lunch   {8.35, 8.51, 10.09, 10.33, 12.48, 13.16, 13.42...
# Male   Dinner  {7.25, 8.77, 7.74, 10.27, 11.61, 12.54, 13.28,...
#        Lunch   {7.51, 8.58, 7.56, 10.34, 11.69, 12.16, 13.03,...
#
#                                                              tip     smoker  \
# gender time
# Female Dinner  {1.0, 2.6, 2.5, 4.0, 4.3, 6.5, 3.5, 3.02, 3.0,...  {Yes, No}
#        Lunch   {1.83, 2.52, 3.5, 2.75, 3.48, 4.19, 2.0, 3.23,...  {Yes, No}
# Male   Dinner  {1.44, 2.0, 3.39, 4.0, 5.0, 5.65, 5.15, 6.5, 4...  {Yes, No}
#        Lunch   {1.92, 2.0, 3.4, 4.0, 5.85, 2.31, 6.7, 1.44, 2...  {Yes, No}
#
#                                  day                size  \
# gender time
# Female Dinner  {Sat, Sun, Fri, Thur}     {1, 2, 3, 4, 5}
#        Lunch             {Fri, Thur}     {1, 2, 3, 4, 6}
# Male   Dinner        {Sat, Sun, Fri}     {2, 3, 4, 5, 6}
#        Lunch             {Fri, Thur}  {1, 2, 3, 4, 5, 6}
#
#                                       percent_tip_wrt_total_bill
# gender time
# Female Dinner  {5.94, 5.68, 7.36, 8.53, 5.64, 10.25, 11.84, 1...
#        Lunch   {7.3, 11.6, 12.52, 13.96, 14.84, 15.38, 15.37,...
# Male   Dinner  {3.56, 6.65, 7.94, 8.82, 9.98, 10.79, 11.89, 1...
#        Lunch   {7.86, 9.55, 9.0, 11.77, 12.7, 13.18, 14.8, 15...

# %%
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  \
# 0        7.25  5.15    Male    Yes  Sun  Dinner     2
# 1        9.60  4.00  Female    Yes  Sun  Dinner     2
#
#    percent_tip_wrt_total_bill
# 0                       71.03
# 1                       41.67

# %%
new_grouped_df = df.groupby(['gender','smoker','day','time']).agg(  total_bill_sum = ('total_bill' , 'sum') ,
                                                                    total_bill_mean = ('total_bill' , 'mean'),
                                                                    total_bill_std = ('total_bill' , 'std') , 
                                                                    num_of_entries = ('total_bill' , 'count')
                                                                 )

# %%
new_grouped_df
# Out:
#                            total_bill_sum  total_bill_mean  total_bill_std  \
# gender smoker day  time
# Female No     Fri  Dinner           22.75        22.750000             NaN
#                    Lunch            15.98        15.980000             NaN
#               Sat  Dinner          247.05        19.003846        6.730219
#               Sun  Dinner          291.54        20.824286        8.396159
#               Thur Dinner           18.78        18.780000             NaN
#                    Lunch           381.58        15.899167        6.904808
#        Yes    Fri  Dinner           48.80        12.200000        4.810121
#                    Lunch            39.78        13.260000        3.093105
#               Sat  Dinner          304.00        20.266667       10.485703
#               Sun  Dinner           66.16        16.540000        4.854764
#               Thur Lunch           121.53        20.255000       11.496491
# Male   No     Fri  Dinner           34.95        17.475000        7.092281
#               Sat  Dinner          637.73        19.929063        9.779061
#               Sun  Dinner          877.34        20.403256        8.140559
#               Thur Lunch           369.73        18.486500        8.739134
#        Yes    Fri  Dinner          129.46        25.892000       10.383290
#                    Lunch            34.16        11.386667        2.510963
#               Sat  Dinner          589.62        21.837778        9.988045
#               Sun  Dinner          392.12        26.141333       10.693824
#               Thur Lunch           191.71        19.171000        6.757421
#
#                            num_of_entries
# gender smoker day  time
# Female No     Fri  Dinner               1
#                    Lunch                1
#               Sat  Dinner              13
#               Sun  Dinner              14
#               Thur Dinner               1
#                    Lunch               24
#        Yes    Fri  Dinner               4
#                    Lunch                3
#               Sat  Dinner              15
#               Sun  Dinner               4
#               Thur Lunch                6
# Male   No     Fri  Dinner               2
#               Sat  Dinner              32
#               Sun  Dinner              43
#               Thur Lunch               20
#        Yes    Fri  Dinner               5
#                    Lunch                3
#               Sat  Dinner              27
#               Sun  Dinner              15
#               Thur Lunch               10

# %%
new_grouped_df.index  # MultiIndex
# Out:
# MultiIndex([('Female',  'No',  'Fri', 'Dinner'),
#             ('Female',  'No',  'Fri',  'Lunch'),
#             ('Female',  'No',  'Sat', 'Dinner'),
#             ('Female',  'No',  'Sun', 'Dinner'),
#             ('Female',  'No', 'Thur', 'Dinner'),
#             ('Female',  'No', 'Thur',  'Lunch'),
#             ('Female', 'Yes',  'Fri', 'Dinner'),
#             ('Female', 'Yes',  'Fri',  'Lunch'),
#             ('Female', 'Yes',  'Sat', 'Dinner'),
#             ('Female', 'Yes',  'Sun', 'Dinner'),
#             ('Female', 'Yes', 'Thur',  'Lunch'),
#             (  'Male',  'No',  'Fri', 'Dinner'),
#             (  'Male',  'No',  'Sat', 'Dinner'),
#             (  'Male',  'No',  'Sun', 'Dinner'),
#             (  'Male',  'No', 'Thur',  'Lunch'),
#             (  'Male', 'Yes',  'Fri', 'Dinner'),
#             (  'Male', 'Yes',  'Fri',  'Lunch'),
#             (  'Male', 'Yes',  'Sat', 'Dinner'),
#             (  'Male', 'Yes',  'Sun', 'Dinner'),
#             (  'Male', 'Yes', 'Thur',  'Lunch')],
#            names=['gender', 'smoker', 'day', 'time'])

# %%
new_grouped_df.loc[ ('Female',  'No') ]
# Out:
#              total_bill_sum  total_bill_mean  total_bill_std  num_of_entries
# day  time
# Fri  Dinner           22.75        22.750000             NaN               1
#      Lunch            15.98        15.980000             NaN               1
# Sat  Dinner          247.05        19.003846        6.730219              13
# Sun  Dinner          291.54        20.824286        8.396159              14
# Thur Dinner           18.78        18.780000             NaN               1
#      Lunch           381.58        15.899167        6.904808              24

# %%
new_grouped_df
# Out:
#                            total_bill_sum  total_bill_mean  total_bill_std  \
# gender smoker day  time
# Female No     Fri  Dinner           22.75        22.750000             NaN
#                    Lunch            15.98        15.980000             NaN
#               Sat  Dinner          247.05        19.003846        6.730219
#               Sun  Dinner          291.54        20.824286        8.396159
#               Thur Dinner           18.78        18.780000             NaN
#                    Lunch           381.58        15.899167        6.904808
#        Yes    Fri  Dinner           48.80        12.200000        4.810121
#                    Lunch            39.78        13.260000        3.093105
#               Sat  Dinner          304.00        20.266667       10.485703
#               Sun  Dinner           66.16        16.540000        4.854764
#               Thur Lunch           121.53        20.255000       11.496491
# Male   No     Fri  Dinner           34.95        17.475000        7.092281
#               Sat  Dinner          637.73        19.929063        9.779061
#               Sun  Dinner          877.34        20.403256        8.140559
#               Thur Lunch           369.73        18.486500        8.739134
#        Yes    Fri  Dinner          129.46        25.892000       10.383290
#                    Lunch            34.16        11.386667        2.510963
#               Sat  Dinner          589.62        21.837778        9.988045
#               Sun  Dinner          392.12        26.141333       10.693824
#               Thur Lunch           191.71        19.171000        6.757421
#
#                            num_of_entries
# gender smoker day  time
# Female No     Fri  Dinner               1
#                    Lunch                1
#               Sat  Dinner              13
#               Sun  Dinner              14
#               Thur Dinner               1
#                    Lunch               24
#        Yes    Fri  Dinner               4
#                    Lunch                3
#               Sat  Dinner              15
#               Sun  Dinner               4
#               Thur Lunch                6
# Male   No     Fri  Dinner               2
#               Sat  Dinner              32
#               Sun  Dinner              43
#               Thur Lunch               20
#        Yes    Fri  Dinner               5
#                    Lunch                3
#               Sat  Dinner              27
#               Sun  Dinner              15
#               Thur Lunch               10

# %%
new_grouped_df.xs( ('Male', 'Fri') , level = (0,2) , drop_level = True) 
# drop level if true drops the mentioned index from output
# Out:
#                total_bill_sum  total_bill_mean  total_bill_std  num_of_entries
# smoker time
# No     Dinner           34.95        17.475000        7.092281               2
# Yes    Dinner          129.46        25.892000       10.383290               5
#        Lunch            34.16        11.386667        2.510963               3

# %%
new_grouped_df.xs(('Male','No') , level = (0,1) , drop_level = True)
# Out:
#              total_bill_sum  total_bill_mean  total_bill_std  num_of_entries
# day  time
# Fri  Dinner           34.95        17.475000        7.092281               2
# Sat  Dinner          637.73        19.929063        9.779061              32
# Sun  Dinner          877.34        20.403256        8.140559              43
# Thur Lunch           369.73        18.486500        8.739134              20

# %%
df.head(5)
# Out:
#    total_bill   tip  gender smoker  day    time  size  \
# 0        7.25  5.15    Male    Yes  Sun  Dinner     2
# 1        9.60  4.00  Female    Yes  Sun  Dinner     2
# 2        3.07  1.00  Female    Yes  Sat  Dinner     1
# 3       11.61  3.39    Male     No  Sat  Dinner     2
# 4       23.17  6.50    Male    Yes  Sun  Dinner     4
#
#    percent_tip_wrt_total_bill
# 0                       71.03
# 1                       41.67
# 2                       32.57
# 3                       29.20
# 4                       28.05

# %%
df.pivot_table(index = 'time' , columns = 'day' , values = 'total_bill' , aggfunc = 'sum')
# Out:
# day        Fri     Sat      Sun     Thur
# time
# Dinner  235.96  1778.4  1627.16    18.78
# Lunch    89.92     NaN      NaN  1064.55

# %%
df.groupby(['time', 'day']).agg({'total_bill' : 'sum'})
# Out:
#              total_bill
# time   day
# Dinner Fri       235.96
#        Sat      1778.40
#        Sun      1627.16
#        Thur       18.78
# Lunch  Fri        89.92
#        Thur     1064.55

# %%
df.pivot_table(index = ['gender','day'] , columns = 'smoker' , values = ['total_bill','tip'] , aggfunc = 'mean')
# df.groupby(['gender','day', 'smoker']).mean(numeric_only = True)
# Out:
#                   tip           total_bill
# smoker             No       Yes         No        Yes
# gender day
# Female Fri   3.125000  2.682857  19.365000  12.654286
#        Sat   2.724615  2.868667  19.003846  20.266667
#        Sun   3.329286  3.500000  20.824286  16.540000
#        Thur  2.459600  3.155000  16.014400  20.255000
# Male   Fri   2.500000  2.741250  17.475000  20.452500
#        Sat   3.256562  2.879259  19.929063  21.837778
#        Sun   3.115349  3.521333  20.403256  26.141333
#        Thur  2.941500  3.058000  18.486500  19.171000

# %%
df.pivot_table(index = ['gender','smoker'] , columns = ['day'] , values = ['total_bill','tip'] , aggfunc = 'mean')
# Out:
#                     tip                             total_bill             \
# day                 Fri       Sat       Sun    Thur        Fri        Sat
# gender smoker
# Female No      3.125000  2.724615  3.329286  2.4596  19.365000  19.003846
#        Yes     2.682857  2.868667  3.500000  3.1550  12.654286  20.266667
# Male   No      2.500000  3.256562  3.115349  2.9415  17.475000  19.929063
#        Yes     2.741250  2.879259  3.521333  3.0580  20.452500  21.837778
#
#
# day                  Sun     Thur
# gender smoker
# Female No      20.824286  16.0144
#        Yes     16.540000  20.2550
# Male   No      20.403256  18.4865
#        Yes     26.141333  19.1710

# %%
df['day'].value_counts(normalize = True) * 100
# Out:
# day
# Sat     35.802469
# Sun     31.275720
# Thur    25.102881
# Fri      7.818930
# Name: proportion, dtype: float64

# %%
df['day']
# Out:
# 0      Sun
# 1      Sun
# 2      Sat
# 3      Sat
# 4      Sun
#       ...
# 239    Sun
# 240    Sun
# 241    Sat
# 242    Sat
# 243    Sat
# Name: day, Length: 243, dtype: object

# %%
def ch(x):
    x = x.replace('Sun','Sunday')
    return x

# %%
ch('Sun')
# Out:
# 'Sunday'

# %%
def change_name(x):
    
    if x == 'Sun':
        return 'Sunday'
    
    if x == 'Mon':
        return 'Monday'
    
    if x == 'Tue':
        return 'Tuesday'
    
    if x == 'Fri':
        return 'Friday' 
    
    if x == 'Sat':
        return 'Saturday' 
    
    else:
        return x

# %%
df.head(6)
# Out:
#    total_bill   tip  gender smoker  day    time  size  \
# 0        7.25  5.15    Male    Yes  Sun  Dinner     2
# 1        9.60  4.00  Female    Yes  Sun  Dinner     2
# 2        3.07  1.00  Female    Yes  Sat  Dinner     1
# 3       11.61  3.39    Male     No  Sat  Dinner     2
# 4       23.17  6.50    Male    Yes  Sun  Dinner     4
# 5       14.31  4.00  Female    Yes  Sat  Dinner     2
#
#    percent_tip_wrt_total_bill
# 0                       71.03
# 1                       41.67
# 2                       32.57
# 3                       29.20
# 4                       28.05
# 5                       27.95

# %%
df['day'].apply( change_name )
# Out:
# 0        Sunday
# 1        Sunday
# 2      Saturday
# 3      Saturday
# 4        Sunday
#          ...
# 239      Sunday
# 240      Sunday
# 241    Saturday
# 242    Saturday
# 243    Saturday
# Name: day, Length: 243, dtype: object

# %%
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  \
# 0        7.25  5.15    Male    Yes  Sun  Dinner     2
# 1        9.60  4.00  Female    Yes  Sun  Dinner     2
#
#    percent_tip_wrt_total_bill
# 0                       71.03
# 1                       41.67

# %%
df['day_name'] = df['day'].apply(change_name)

# %%
df.head(6)
# Out:
#    total_bill   tip  gender smoker  day    time  size  \
# 0        7.25  5.15    Male    Yes  Sun  Dinner     2
# 1        9.60  4.00  Female    Yes  Sun  Dinner     2
# 2        3.07  1.00  Female    Yes  Sat  Dinner     1
# 3       11.61  3.39    Male     No  Sat  Dinner     2
# 4       23.17  6.50    Male    Yes  Sun  Dinner     4
# 5       14.31  4.00  Female    Yes  Sat  Dinner     2
#
#    percent_tip_wrt_total_bill  day_name
# 0                       71.03    Sunday
# 1                       41.67    Sunday
# 2                       32.57  Saturday
# 3                       29.20  Saturday
# 4                       28.05    Sunday
# 5                       27.95  Saturday

# %%
df['comb'] = df['gender'] + '_' + df['smoker']

# %%
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  \
# 0        7.25  5.15    Male    Yes  Sun  Dinner     2
# 1        9.60  4.00  Female    Yes  Sun  Dinner     2
#
#    percent_tip_wrt_total_bill day_name        comb
# 0                       71.03   Sunday    Male_Yes
# 1                       41.67   Sunday  Female_Yes

# %%
df['new_col'] = df['comb'].apply( lambda x : x.split('_')[1] )

# %%
df.sample(8)  # gives random rows as output
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 130       13.13  2.00    Male     No   Sun  Dinner     2
# 118       11.24  1.76    Male    Yes   Sat  Dinner     2
# 19        22.23  5.00    Male     No   Sun  Dinner     2
# 166       15.01  2.09    Male    Yes   Sat  Dinner     2
# 26        18.71  4.00    Male    Yes  Thur   Lunch     3
# 31        18.29  3.76    Male    Yes   Sat  Dinner     4
# 53        20.92  4.08  Female     No   Sat  Dinner     2
# 68         7.74  1.44    Male    Yes   Sat  Dinner     2
#
#      percent_tip_wrt_total_bill  day_name       comb new_col
# 130                       15.23    Sunday    Male_No      No
# 118                       15.66  Saturday   Male_Yes     Yes
# 19                        22.49    Sunday    Male_No      No
# 166                       13.92  Saturday   Male_Yes     Yes
# 26                        21.38      Thur   Male_Yes     Yes
# 31                        20.56  Saturday   Male_Yes     Yes
# 53                        19.50  Saturday  Female_No      No
# 68                        18.60  Saturday   Male_Yes     Yes

# %%
def dis(x):
    if x == 'Sunday':
        return 'Discount Allowed'
    else:
        return 'No Discount'

df['Discount'] = df['day_name'].apply(dis)

# %%
df.sample(7)
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 5         14.31  4.00  Female    Yes   Sat  Dinner     2
# 221       22.82  2.18    Male     No  Thur   Lunch     3
# 135       25.00  3.75  Female     No   Sun  Dinner     4
# 196       12.46  1.50    Male     No   Fri  Dinner     2
# 91        17.92  3.08    Male    Yes   Sat  Dinner     2
# 12        16.58  4.00    Male    Yes  Thur   Lunch     2
# 99        18.04  3.00    Male     No   Sun  Dinner     2
#
#      percent_tip_wrt_total_bill  day_name        comb new_col  \
# 5                         27.95  Saturday  Female_Yes     Yes
# 221                        9.55      Thur     Male_No      No
# 135                       15.00    Sunday   Female_No      No
# 196                       12.04    Friday     Male_No      No
# 91                        17.19  Saturday    Male_Yes     Yes
# 12                        24.13      Thur    Male_Yes     Yes
# 99                        16.63    Sunday     Male_No      No
#
#              Discount
# 5         No Discount
# 221       No Discount
# 135  Discount Allowed
# 196       No Discount
# 91        No Discount
# 12        No Discount
# 99   Discount Allowed

# %%
df.loc[ (df['day_name'] == 'Sunday')  &  (df['time'] == 'Dinner') , : ]
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 0          7.25  5.15    Male    Yes  Sun  Dinner     2
# 1          9.60  4.00  Female    Yes  Sun  Dinner     2
# 4         23.17  6.50    Male    Yes  Sun  Dinner     4
# 9         10.29  2.60  Female     No  Sun  Dinner     2
# 10        23.33  5.65    Male    Yes  Sun  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 233       45.35  3.50    Male    Yes  Sun  Dinner     3
# 234       40.55  3.00    Male    Yes  Sun  Dinner     2
# 237       28.55  2.05    Male     No  Sun  Dinner     3
# 239       30.46  2.00    Male    Yes  Sun  Dinner     5
# 240       16.99  1.01  Female     No  Sun  Dinner     2
#
#      percent_tip_wrt_total_bill day_name        comb new_col          Discount
# 0                         71.03   Sunday    Male_Yes     Yes  Discount Allowed
# 1                         41.67   Sunday  Female_Yes     Yes  Discount Allowed
# 4                         28.05   Sunday    Male_Yes     Yes  Discount Allowed
# 9                         25.27   Sunday   Female_No      No  Discount Allowed
# 10                        24.22   Sunday    Male_Yes     Yes  Discount Allowed
# ..                          ...      ...         ...     ...               ...
# 233                        7.72   Sunday    Male_Yes     Yes  Discount Allowed
# 234                        7.40   Sunday    Male_Yes     Yes  Discount Allowed
# 237                        7.18   Sunday     Male_No      No  Discount Allowed
# 239                        6.57   Sunday    Male_Yes     Yes  Discount Allowed
# 240                        5.94   Sunday   Female_No      No  Discount Allowed
#
# [76 rows x 12 columns]

# %%
df.loc[ (df['day_name'] == 'Sunday')  &  (df['time'] == 'Dinner') , 'Discount'] = 'Condition Discount'

# %%
df.sample(5)
# Out:
#      total_bill   tip  gender smoker   day    time  size  \
# 223       28.44  2.56    Male    Yes  Thur   Lunch     2
# 120       25.71  4.00  Female     No   Sun  Dinner     3
# 185       15.95  2.00    Male     No  Thur   Lunch     2
# 215       15.42  1.57    Male     No   Sun  Dinner     2
# 59        18.15  3.50  Female    Yes   Sun  Dinner     3
#
#      percent_tip_wrt_total_bill day_name        comb new_col  \
# 223                        9.00     Thur    Male_Yes     Yes
# 120                       15.56   Sunday   Female_No      No
# 185                       12.54     Thur     Male_No      No
# 215                       10.18   Sunday     Male_No      No
# 59                        19.28   Sunday  Female_Yes     Yes
#
#                Discount
# 223         No Discount
# 120  Condition Discount
# 185         No Discount
# 215  Condition Discount
# 59   Condition Discount

# %%
df.loc[ ~ (df['day_name'] == 'Sunday') & (df['time'] == 'Dinner') , : ]
# Out:
#      total_bill   tip  gender smoker  day    time  size  \
# 2          3.07  1.00  Female    Yes  Sat  Dinner     1
# 3         11.61  3.39    Male     No  Sat  Dinner     2
# 5         14.31  4.00  Female    Yes  Sat  Dinner     2
# 7         16.32  4.30  Female    Yes  Fri  Dinner     2
# 15        28.17  6.50  Female    Yes  Sat  Dinner     3
# ..          ...   ...     ...    ...  ...     ...   ...
# 235       27.18  2.00  Female    Yes  Sat  Dinner     2
# 238       30.06  2.00    Male    Yes  Sat  Dinner     3
# 241       26.41  1.50  Female     No  Sat  Dinner     2
# 242       44.30  2.50  Female    Yes  Sat  Dinner     3
# 243       32.83  1.17    Male    Yes  Sat  Dinner     2
#
#      percent_tip_wrt_total_bill  day_name        comb new_col     Discount
# 2                         32.57  Saturday  Female_Yes     Yes  No Discount
# 3                         29.20  Saturday     Male_No      No  No Discount
# 5                         27.95  Saturday  Female_Yes     Yes  No Discount
# 7                         26.35    Friday  Female_Yes     Yes  No Discount
# 15                        23.07  Saturday  Female_Yes     Yes  No Discount
# ..                          ...       ...         ...     ...          ...
# 235                        7.36  Saturday  Female_Yes     Yes  No Discount
# 238                        6.65  Saturday    Male_Yes     Yes  No Discount
# 241                        5.68  Saturday   Female_No      No  No Discount
# 242                        5.64  Saturday  Female_Yes     Yes  No Discount
# 243                        3.56  Saturday    Male_Yes     Yes  No Discount
#
# [100 rows x 12 columns]

# %%
df.loc[ ~ (df['day_name'] == 'Sunday') & (df['time'] == 'Dinner') , 'Discount'] = 'Condition No Discount'

# %%
df.head(5)
# Out:
#    total_bill   tip  gender smoker  day    time  size  \
# 0        7.25  5.15    Male    Yes  Sun  Dinner     2
# 1        9.60  4.00  Female    Yes  Sun  Dinner     2
# 2        3.07  1.00  Female    Yes  Sat  Dinner     1
# 3       11.61  3.39    Male     No  Sat  Dinner     2
# 4       23.17  6.50    Male    Yes  Sun  Dinner     4
#
#    percent_tip_wrt_total_bill  day_name        comb new_col  \
# 0                       71.03    Sunday    Male_Yes     Yes
# 1                       41.67    Sunday  Female_Yes     Yes
# 2                       32.57  Saturday  Female_Yes     Yes
# 3                       29.20  Saturday     Male_No      No
# 4                       28.05    Sunday    Male_Yes     Yes
#
#                 Discount
# 0     Condition Discount
# 1     Condition Discount
# 2  Condition No Discount
# 3  Condition No Discount
# 4     Condition Discount

# %%
# df.to_   # press tab to see all formats in which you can store your data

# %%
# df.to_csv('manipulated_data.csv')  # will save to your present working directory

# %%
date_df = pd.DataFrame({'date':['25-08-2025', '29-08-2025', '30-08-2025']})
date_df
# Out:
#          date
# 0  25-08-2025
# 1  29-08-2025
# 2  30-08-2025

# %%
# df[(df['date'] > '28-02-2022')  & (df['date'] < '28-10-2022')]   # this is not possible with strings

# %%
date_df.dtypes
# Out:
# date    object
# dtype: object

# %%
date_df['in_datetime_format'] = pd.to_datetime(date_df['date'] , format = '%d-%m-%Y')  
                                                                        #  30-08-2024

# %%
date_df
# Out:
#          date in_datetime_format
# 0  25-08-2025         2025-08-25
# 1  29-08-2025         2025-08-29
# 2  30-08-2025         2025-08-30

# %%
date_df.dtypes
# Out:
# date                          object
# in_datetime_format    datetime64[ns]
# dtype: object

# %%
date_df['in_datetime_format'].max()
# Out:
# Timestamp('2025-08-30 00:00:00')

# %%
date_df['year'] = date_df['in_datetime_format'].dt.year
date_df
# Out:
#          date in_datetime_format  year
# 0  25-08-2025         2025-08-25  2025
# 1  29-08-2025         2025-08-29  2025
# 2  30-08-2025         2025-08-30  2025

# %%
date_df.dtypes
# Out:
# date                          object
# in_datetime_format    datetime64[ns]
# year                           int32
# dtype: object

# %%
date_df['month'] = date_df['in_datetime_format'].dt.month
date_df
# Out:
#          date in_datetime_format  year  month
# 0  25-08-2025         2025-08-25  2025      8
# 1  29-08-2025         2025-08-29  2025      8
# 2  30-08-2025         2025-08-30  2025      8

# %%
date_df['day'] = date_df['in_datetime_format'].dt.day
date_df
# Out:
#          date in_datetime_format  year  month  day
# 0  25-08-2025         2025-08-25  2025      8   25
# 1  29-08-2025         2025-08-29  2025      8   29
# 2  30-08-2025         2025-08-30  2025      8   30

# %%
date_df['month_name'] = date_df['in_datetime_format'].dt.month_name()
date_df
# Out:
#          date in_datetime_format  year  month  day month_name
# 0  25-08-2025         2025-08-25  2025      8   25     August
# 1  29-08-2025         2025-08-29  2025      8   29     August
# 2  30-08-2025         2025-08-30  2025      8   30     August

# %%
date_df['weekday'] = date_df['in_datetime_format'].dt.weekday
date_df
# Out:
#          date in_datetime_format  year  month  day month_name  weekday
# 0  25-08-2025         2025-08-25  2025      8   25     August        0
# 1  29-08-2025         2025-08-29  2025      8   29     August        4
# 2  30-08-2025         2025-08-30  2025      8   30     August        5

# %%
date_df['quarter'] = date_df['in_datetime_format'].dt.quarter
date_df
# Out:
#          date in_datetime_format  year  month  day month_name  weekday  \
# 0  25-08-2025         2025-08-25  2025      8   25     August        0
# 1  29-08-2025         2025-08-29  2025      8   29     August        4
# 2  30-08-2025         2025-08-30  2025      8   30     August        5
#
#    quarter
# 0        3
# 1        3
# 2        3

# %% [markdown]
# ### Merging

# %%
x = pd.DataFrame({'name': ['AB', 'Gayle', 'virat', 'wade' , 'warner'],
                  'age': [34,23,56,22 , 33],
                  'contact': [22,66,56,78, 32]})
   
y = pd.DataFrame({'name': ['AB', 'Gayle', 'virat', 'wade' , 'Rohit'],
                  'country': ['SA', 'WI', 'India', 'AUS','India'],
                  'Jersey': [17,333,18,15,45]})

# %%
x
# Out:
#      name  age  contact
# 0      AB   34       22
# 1   Gayle   23       66
# 2   virat   56       56
# 3    wade   22       78
# 4  warner   33       32

# %%
y
# Out:
#     name country  Jersey
# 0     AB      SA      17
# 1  Gayle      WI     333
# 2  virat   India      18
# 3   wade     AUS      15
# 4  Rohit   India      45

# %%
pd.merge(left = x , right = y , on = 'name' , how = 'inner')
# Out:
#     name  age  contact country  Jersey
# 0     AB   34       22      SA      17
# 1  Gayle   23       66      WI     333
# 2  virat   56       56   India      18
# 3   wade   22       78     AUS      15

# %%
pd.merge(left = x , right = y  , on = 'name' , how = 'outer')
# Out:
#      name   age  contact country  Jersey
# 0      AB  34.0     22.0      SA    17.0
# 1   Gayle  23.0     66.0      WI   333.0
# 2   Rohit   NaN      NaN   India    45.0
# 3   virat  56.0     56.0   India    18.0
# 4    wade  22.0     78.0     AUS    15.0
# 5  warner  33.0     32.0     NaN     NaN

# %%
pd.merge(left = x , right = y , on = 'name' , how = 'left' )
# Out:
#      name  age  contact country  Jersey
# 0      AB   34       22      SA    17.0
# 1   Gayle   23       66      WI   333.0
# 2   virat   56       56   India    18.0
# 3    wade   22       78     AUS    15.0
# 4  warner   33       32     NaN     NaN

# %%
pd.merge(left = x , right = y , on = 'name' , how = 'right' )
# Out:
#     name   age  contact country  Jersey
# 0     AB  34.0     22.0      SA      17
# 1  Gayle  23.0     66.0      WI     333
# 2  virat  56.0     56.0   India      18
# 3   wade  22.0     78.0     AUS      15
# 4  Rohit   NaN      NaN   India      45

# %%
# pd.merge(x , y , how = 'cross')
pd.merge(x['name'] , y['name'] , how = 'cross')
# Out:
#     name_x name_y
# 0       AB     AB
# 1       AB  Gayle
# 2       AB  virat
# 3       AB   wade
# 4       AB  Rohit
# 5    Gayle     AB
# 6    Gayle  Gayle
# 7    Gayle  virat
# 8    Gayle   wade
# 9    Gayle  Rohit
# 10   virat     AB
# 11   virat  Gayle
# 12   virat  virat
# 13   virat   wade
# 14   virat  Rohit
# 15    wade     AB
# 16    wade  Gayle
# 17    wade  virat
# 18    wade   wade
# 19    wade  Rohit
# 20  warner     AB
# 21  warner  Gayle
# 22  warner  virat
# 23  warner   wade
# 24  warner  Rohit

# %% [markdown]
# ### Concat

# %%
may = pd.DataFrame({'day': [21, 22, 23, 24], 'sales': [100, 200, 110, 160]})

june = pd.DataFrame({'day': [1, 2, 3, 4], 'sales': [210, 180, 190, 96]})

july = pd.DataFrame({'day': [16, 17, 18, 19], 'sales': [160, 114, 110, 150]})

# %%
may
# Out:
#    day  sales
# 0   21    100
# 1   22    200
# 2   23    110
# 3   24    160

# %%
june
# Out:
#    day  sales
# 0    1    210
# 1    2    180
# 2    3    190
# 3    4     96

# %%
july
# Out:
#    day  sales
# 0   16    160
# 1   17    114
# 2   18    110
# 3   19    150

# %%
pd.concat( [ may , june , july ] , axis = 0 )
# Out:
#    day  sales
# 0   21    100
# 1   22    200
# 2   23    110
# 3   24    160
# 0    1    210
# 1    2    180
# 2    3    190
# 3    4     96
# 0   16    160
# 1   17    114
# 2   18    110
# 3   19    150

# %%
pd.concat( [ may , june , july ] , axis = 0 , ignore_index = True )
# Out:
#     day  sales
# 0    21    100
# 1    22    200
# 2    23    110
# 3    24    160
# 4     1    210
# 5     2    180
# 6     3    190
# 7     4     96
# 8    16    160
# 9    17    114
# 10   18    110
# 11   19    150

# %%
pd.concat( [ may , june , july ] , axis = 1 )
# Out:
#    day  sales  day  sales  day  sales
# 0   21    100    1    210   16    160
# 1   22    200    2    180   17    114
# 2   23    110    3    190   18    110
# 3   24    160    4     96   19    150

# %%
may = pd.DataFrame({'day': [21, 22, 23, 24], 'sales': [100, 200, 110, 160]} , index = [0,1,2,3])

june = pd.DataFrame({'day': [1, 2, 3, 4], 'sales': [210, 180, 190, 96]} , index = [4,5,6,7])

july = pd.DataFrame({'day': [16, 17, 18, 19], 'sales': [160, 114, 110, 150]} , index = [7,8,9,10])

# %%
pd.concat( [ may , june , july ] , axis = 1 ).fillna('')
# Out:
#      day  sales  day  sales   day  sales
# 0   21.0  100.0
# 1   22.0  200.0
# 2   23.0  110.0
# 3   24.0  160.0
# 4                1.0  210.0
# 5                2.0  180.0
# 6                3.0  190.0
# 7                4.0   96.0  16.0  160.0
# 8                            17.0  114.0
# 9                            18.0  110.0
# 10                           19.0  150.0

# %%
pd.concat( [ may , june , july ] , axis = 1 , ignore_index = True )
# Out:
#        0      1    2      3     4      5
# 0   21.0  100.0  NaN    NaN   NaN    NaN
# 1   22.0  200.0  NaN    NaN   NaN    NaN
# 2   23.0  110.0  NaN    NaN   NaN    NaN
# 3   24.0  160.0  NaN    NaN   NaN    NaN
# 4    NaN    NaN  1.0  210.0   NaN    NaN
# 5    NaN    NaN  2.0  180.0   NaN    NaN
# 6    NaN    NaN  3.0  190.0   NaN    NaN
# 7    NaN    NaN  4.0   96.0  16.0  160.0
# 8    NaN    NaN  NaN    NaN  17.0  114.0
# 9    NaN    NaN  NaN    NaN  18.0  110.0
# 10   NaN    NaN  NaN    NaN  19.0  150.0

# %%
# li = []

# for i in [ may , june , july ]:
#     i = i.reset_index(drop = True)
#     li.append(i)

# pd.concat(li , axis = 1)

pd.concat(  [ i.reset_index(drop = True) for i in [ may , june , july ]  ]  , axis = 1    )  # list comprehension for line 4-10
# final_df = pd.concat(li , axis = 1)
# Out:
#    day  sales  day  sales  day  sales
# 0   21    100    1    210   16    160
# 1   22    200    2    180   17    114
# 2   23    110    3    190   18    110
# 3   24    160    4     96   19    150
